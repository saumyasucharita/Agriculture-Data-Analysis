# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mticker

# %%
prod_ind_data = pd.read_csv('Dataset/archive/fao_data_production_indices_data.csv')

# %%
prod_ind_data
prod_ind_data['year']=prod_ind_data['year'].astype(pd.Int64Dtype())

# %%
 print(prod_ind_data.category.unique())
# Out:
# ['agriculture_pin' 'crops_pin' 'food_pin' 'livestock_pin' 'non_food_pin']

# %%
agri_data = prod_ind_data[prod_ind_data['category']=='agriculture_pin']
agri_data
# Out:
#       country_or_area                                       element_code  \
# 0         Afghanistan                                                152
# 1         Afghanistan                                                152
# 2         Afghanistan                                                152
# 3         Afghanistan                                                152
# 4         Afghanistan                                                152
# ...               ...                                                ...
# 64093        Zimbabwe                                                438
# 64094        Zimbabwe                                                438
# 64095        Zimbabwe                                                438
# 64096         fnSeqID                                           Footnote
# 64097              A   May include official, semi-official or estimat...
#
#                                     element  year         unit      value  \
# 0      Gross Production 1999-2001 (1000 I$)  2007  1000 Int. $  2486910.0
# 1      Gross Production 1999-2001 (1000 I$)  2006  1000 Int. $  2278516.0
# 2      Gross Production 1999-2001 (1000 I$)  2005  1000 Int. $  2524097.0
# 3      Gross Production 1999-2001 (1000 I$)  2004  1000 Int. $  2226346.0
# 4      Gross Production 1999-2001 (1000 I$)  2003  1000 Int. $  2289434.0
# ...                                     ...   ...          ...        ...
# 64093   Net per capita PIN (base 1999-2001)  1963       Int. $      113.0
# 64094   Net per capita PIN (base 1999-2001)  1962       Int. $      127.0
# 64095   Net per capita PIN (base 1999-2001)  1961       Int. $      124.0
# 64096                                   NaN  <NA>          NaN        NaN
# 64097                                   NaN  <NA>          NaN        NaN
#
#       value_footnotes         category
# 0                  A   agriculture_pin
# 1                  A   agriculture_pin
# 2                  A   agriculture_pin
# 3                  A   agriculture_pin
# 4                  A   agriculture_pin
# ...               ...              ...
# 64093              A   agriculture_pin
# 64094              A   agriculture_pin
# 64095              A   agriculture_pin
# 64096             NaN  agriculture_pin
# 64097             NaN  agriculture_pin
#
# [64098 rows x 8 columns]

# %%
agri_data.columns
# Out:
# Index(['country_or_area', 'element_code', 'element', 'year', 'unit', 'value',
#        'value_footnotes', 'category'],
#       dtype='object')

# %%
missing_cols = agri_data.columns[agri_data.isnull().any()]
print(missing_cols)
# Out:
# Index(['element', 'year', 'unit', 'value', 'value_footnotes'], dtype='object')

# %%
#Remove rows that contain null values
agri_data.dropna(inplace=True)
agri_data
# Out:
# C:\Users\saumy\AppData\Local\Temp\ipykernel_23456\4138272869.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agri_data.dropna(inplace=True)
#       country_or_area element_code                               element  \
# 0         Afghanistan          152  Gross Production 1999-2001 (1000 I$)
# 1         Afghanistan          152  Gross Production 1999-2001 (1000 I$)
# 2         Afghanistan          152  Gross Production 1999-2001 (1000 I$)
# 3         Afghanistan          152  Gross Production 1999-2001 (1000 I$)
# 4         Afghanistan          152  Gross Production 1999-2001 (1000 I$)
# ...               ...          ...                                   ...
# 64091        Zimbabwe          438   Net per capita PIN (base 1999-2001)
# 64092        Zimbabwe          438   Net per capita PIN (base 1999-2001)
# 64093        Zimbabwe          438   Net per capita PIN (base 1999-2001)
# 64094        Zimbabwe          438   Net per capita PIN (base 1999-2001)
# 64095        Zimbabwe          438   Net per capita PIN (base 1999-2001)
#
#        year         unit      value value_footnotes         category
# 0      2007  1000 Int. $  2486910.0              A   agriculture_pin
# 1      2006  1000 Int. $  2278516.0              A   agriculture_pin
# 2      2005  1000 Int. $  2524097.0              A   agriculture_pin
# 3      2004  1000 Int. $  2226346.0              A   agriculture_pin
# 4      2003  1000 Int. $  2289434.0              A   agriculture_pin
# ...     ...          ...        ...             ...              ...
# 64091  1965       Int. $      113.0              A   agriculture_pin
# 64092  1964       Int. $      128.0              A   agriculture_pin
# 64093  1963       Int. $      113.0              A   agriculture_pin
# 64094  1962       Int. $      127.0              A   agriculture_pin
# 64095  1961       Int. $      124.0              A   agriculture_pin
#
# [64096 rows x 8 columns]

# %%
print(agri_data.element.unique())
# Out:
# ['Gross Production 1999-2001 (1000 I$)'
#  'Net Production 1999-2001 (1000 I$)' 'Gross PIN (base 1999-2001)'
#  'Grs per capita PIN (base 1999-2001)' 'Net PIN (base 1999-2001)'
#  'Net per capita PIN (base 1999-2001)']

# %%
gross_prod_data = agri_data.drop(agri_data[agri_data['element'] != 'Gross Production 1999-2001 (1000 I$)'].index)
gross_prod_data
# Out:
#       country_or_area element_code                               element  \
# 0         Afghanistan          152  Gross Production 1999-2001 (1000 I$)
# 1         Afghanistan          152  Gross Production 1999-2001 (1000 I$)
# 2         Afghanistan          152  Gross Production 1999-2001 (1000 I$)
# 3         Afghanistan          152  Gross Production 1999-2001 (1000 I$)
# 4         Afghanistan          152  Gross Production 1999-2001 (1000 I$)
# ...               ...          ...                                   ...
# 63856        Zimbabwe          152  Gross Production 1999-2001 (1000 I$)
# 63857        Zimbabwe          152  Gross Production 1999-2001 (1000 I$)
# 63858        Zimbabwe          152  Gross Production 1999-2001 (1000 I$)
# 63859        Zimbabwe          152  Gross Production 1999-2001 (1000 I$)
# 63860        Zimbabwe          152  Gross Production 1999-2001 (1000 I$)
#
#        year         unit      value value_footnotes         category
# 0      2007  1000 Int. $  2486910.0              A   agriculture_pin
# 1      2006  1000 Int. $  2278516.0              A   agriculture_pin
# 2      2005  1000 Int. $  2524097.0              A   agriculture_pin
# 3      2004  1000 Int. $  2226346.0              A   agriculture_pin
# 4      2003  1000 Int. $  2289434.0              A   agriculture_pin
# ...     ...          ...        ...             ...              ...
# 63856  1965  1000 Int. $   687546.0              A   agriculture_pin
# 63857  1964  1000 Int. $   740738.0              A   agriculture_pin
# 63858  1963  1000 Int. $   625430.0              A   agriculture_pin
# 63859  1962  1000 Int. $   679806.0              A   agriculture_pin
# 63860  1961  1000 Int. $   640644.0              A   agriculture_pin
#
# [10779 rows x 8 columns]

# %%
focused_data = gross_prod_data[['country_or_area', 'year', 'value']]
focused_data.head()
# Out:
#   country_or_area  year      value
# 0     Afghanistan  2007  2486910.0
# 1     Afghanistan  2006  2278516.0
# 2     Afghanistan  2005  2524097.0
# 3     Afghanistan  2004  2226346.0
# 4     Afghanistan  2003  2289434.0

# %%
#Rename columns
focused_data.columns = ['Country', 'Year', 'Gross_Production']
focused_data.head()
# Out:
#        Country  Year  Gross_Production
# 0  Afghanistan  2007         2486910.0
# 1  Afghanistan  2006         2278516.0
# 2  Afghanistan  2005         2524097.0
# 3  Afghanistan  2004         2226346.0
# 4  Afghanistan  2003         2289434.0

# %%
# Pivot the DataFrame
pivot_df = focused_data.pivot(index='Country', columns='Year', values='Gross_Production')

# Print the resulting pivoted DataFrame
print(pivot_df.head())
# Out:
# Year                  1961        1962        1963        1964        1965  \
# Country
# Afghanistan      1365296.0   1393857.0   1399596.0   1489104.0   1550441.0
# Africa +        40235510.0  42469530.0  44027500.0  44810030.0  45741720.0
# Albania           254771.0    274898.0    274310.0    301150.0    291325.0
# Algeria          1639496.0   1738226.0   1742950.0   1551149.0   1793427.0
# American Samoa      1750.0      1785.0      2000.0      2005.0      2057.0
#
# Year                  1966        1967        1968        1969        1970  \
# Country
# Afghanistan      1575538.0   1717742.0   1790886.0   1829964.0   1658073.0
# Africa +        45589030.0  48631010.0  49961520.0  52174760.0  54258640.0
# Albania           329062.0    343560.0    343240.0    351221.0    366693.0
# Algeria          1209707.0   1345804.0   1729201.0   1601248.0   1658379.0
# American Samoa      2104.0      1941.0      1875.0      1921.0      1850.0
#
# Year            ...         1998         1999         2000         2001  \
# Country         ...
# Afghanistan     ...    2373424.0    2345362.0    1935142.0    1863022.0
# Africa +        ...  105472200.0  109259900.0  110363900.0  113037800.0
# Albania         ...     706612.0     700072.0     733849.0     747971.0
# Algeria         ...    3033235.0    3107780.0    2941046.0    3215132.0
# American Samoa  ...       2221.0       1781.0       1872.0       2054.0
#
# Year                   2002         2003         2004         2005  \
# Country
# Afghanistan       2216530.0    2289434.0    2226346.0    2524097.0
# Africa +        116928400.0  122382000.0  126063000.0  130236700.0
# Albania            755188.0     789269.0     819870.0     813707.0
# Algeria           3269373.0    3863700.0    4211766.0    4221735.0
# American Samoa       2126.0       2469.0       2365.0       2365.0
#
# Year                   2006         2007
# Country
# Afghanistan       2278516.0    2486910.0
# Africa +        135449900.0  130351100.0
# Albania            858366.0     824818.0
# Algeria           4404404.0    4225072.0
# American Samoa       2403.0       2415.0
#
# [5 rows x 47 columns]

# %%
# Calculate the total Gross_Production for each country
pivot_df['Total'] = pivot_df.sum(axis=1)

pivot_df.sort_values(['Total'], ascending=False, axis=0, inplace=True)

print(pivot_df.head())
# Out:
# Year                   1961         1962         1963         1964  \
# Country
# World +         607542000.0  627390800.0  642877400.0  666254900.0
# Asia +          179038900.0  184564800.0  191333500.0  199301800.0
# Europe +        224694200.0  231333600.0  231958200.0  244458600.0
# Americas +      151225800.0  155494300.0  161601700.0  162971000.0
# Eastern Asia +   73769500.0   76666790.0   80440290.0   85929400.0
#
# Year                   1965         1966         1967         1968  \
# Country
# World +         678915200.0  704418100.0  729306100.0  751235800.0
# Asia +          203996300.0  211505700.0  218894900.0  225444700.0
# Europe +        244380200.0  260177100.0  269648400.0  278052900.0
# Americas +      170410400.0  171724600.0  177427800.0  181386000.0
# Eastern Asia +   92461040.0   98721230.0  100686100.0  101181100.0
#
# Year                   1969         1970  ...          1999          2000  \
# Country                                   ...
# World +         754067300.0  777022300.0  ...  1.445347e+09  1.471887e+09
# Asia +          230101100.0  239643400.0  ...  6.753094e+08  6.927565e+08
# Europe +        271058600.0  281849600.0  ...  2.848948e+08  2.856533e+08
# Americas +      184583300.0  184769600.0  ...  3.506003e+08  3.574944e+08
# Eastern Asia +  102360900.0  106804300.0  ...  3.325128e+08  3.435530e+08
#
# Year                    2001          2002          2003          2004  \
# Country
# World +         1.494380e+09  1.509848e+09  1.549756e+09  1.621487e+09
# Asia +          7.072426e+08  7.199523e+08  7.453802e+08  7.727483e+08
# Europe +        2.881761e+08  2.899681e+08  2.798774e+08  3.013701e+08
# Americas +      3.592452e+08  3.599183e+08  3.760901e+08  3.959850e+08
# Eastern Asia +  3.506587e+08  3.640838e+08  3.674522e+08  3.881589e+08
#
# Year                    2005          2006          2007         Total
# Country
# World +         1.650582e+09  1.663516e+09  1.692538e+09  5.124231e+10
# Asia +          8.016780e+08  8.245719e+08  8.449839e+08  2.029140e+10
# Europe +        2.910385e+08  2.849791e+08  2.824522e+08  1.402193e+10
# Americas +      4.008277e+08  3.950258e+08  4.115540e+08  1.236547e+10
# Eastern Asia +  3.995142e+08  4.075642e+08  4.141032e+08  9.611154e+09
#
# [5 rows x 48 columns]

# %%
world_total_prod = pivot_df[pivot_df.index.str.contains('World +')]['Total']
world_1961_prod = pivot_df[pivot_df.index.str.contains('World +')][1961]
world_2007_prod = pivot_df[pivot_df.index.str.contains('World +')][2007]
print(world_total_prod)
print(world_1961_prod)
print(world_2007_prod)
# Out:
# Country
# World +    5.124231e+10
# Name: Total, dtype: float64
# Country
# World +    607542000.0
# Name: 1961, dtype: float64
# Country
# World +    1.692538e+09
# Name: 2007, dtype: float64

# %%
#Remove countries with + at the end like World + as it includes all the countries in the world
# Filter out rows with row headers ending in "+"
filtered_df = pivot_df[~pivot_df.index.str.endswith('+')]

# Print the resulting DataFrame
print(filtered_df.head(10))
# Out:
# Year                            1961        1962        1963        1964  \
# Country
# China                     58340740.0  60690860.0  63942700.0  68462610.0
# United States of America  89816580.0  90275010.0  93700380.0  94323650.0
# India                     50142680.0  50015760.0  51367730.0  52267720.0
# USSR                      72768810.0  73961920.0  70531000.0  81216890.0
# Brazil                    16564600.0  17344940.0  17443010.0  17658130.0
# France                    23408500.0  26654000.0  25202710.0  25321080.0
# Germany                   22077690.0  24241470.0  25340780.0  24843610.0
# Italy                     18638310.0  19289340.0  18918070.0  19893760.0
# Argentina                 11950390.0  12519320.0  13694660.0  12918230.0
# Indonesia                  7383684.0   8054871.0   7650931.0   8076970.0
#
# Year                            1965        1966         1967         1968  \
# Country
# China                     74747900.0  80445930.0   81718660.0   81474800.0
# United States of America  97704050.0  97277180.0  101177900.0  103420600.0
# India                     49498330.0  49309560.0   52731470.0   55208160.0
# USSR                      80941960.0  90781310.0   92659220.0   98507460.0
# Brazil                    20367240.0  19238750.0   20650260.0   21256810.0
# France                    26780910.0  25447410.0   27156150.0   28165500.0
# Germany                   23988490.0  25236310.0   27208190.0   27321930.0
# Italy                     20564500.0  21158350.0   22352040.0   21546680.0
# Argentina                 12247380.0  13410430.0   14588430.0   13747960.0
# Indonesia                  7925503.0   8219212.0    7840406.0    9096512.0
#
# Year                             1969         1970  ...         1999  \
# Country                                             ...
# China                      82195340.0   86542200.0  ...  304490200.0
# United States of America  104285200.0  102786400.0  ...  170083400.0
# India                      56970870.0   60053830.0  ...  143567200.0
# USSR                       93745540.0  100571500.0  ...          NaN
# Brazil                     22008700.0   22533890.0  ...   65353180.0
# France                     26664590.0   28293850.0  ...   38125640.0
# Germany                    26233890.0   27169910.0  ...   29794080.0
# Italy                      22380610.0   22301020.0  ...   26866340.0
# Argentina                  14798930.0   14611240.0  ...   26567310.0
# Indonesia                   9155070.0    9704501.0  ...   26909240.0
#
# Year                             2000         2001         2002         2003  \
# Country
# China                     315511100.0  322771800.0  336394800.0  340623800.0
# United States of America  173640200.0  170755800.0  167494400.0  172458200.0
# India                     142989200.0  147351100.0  137112300.0  151552000.0
# USSR                              NaN          NaN          NaN          NaN
# Brazil                     67416260.0   71250310.0   75603330.0   81198510.0
# France                     37449710.0   35782140.0   37868760.0   34763540.0
# Germany                    30055110.0   29948860.0   29032560.0   27700560.0
# Italy                      26136650.0   25580200.0   24916050.0   23984610.0
# Argentina                  26422920.0   26443270.0   25764360.0   27464940.0
# Indonesia                  27894050.0   28467300.0   30238130.0   32107000.0
#
# Year                             2004         2005         2006         2007  \
# Country
# China                     360834700.0  371939300.0  380320200.0  386448200.0
# United States of America  183519100.0  181432900.0  176803000.0  184698800.0
# India                     149552600.0  156869200.0  164974800.0  175747700.0
# USSR                              NaN          NaN          NaN          NaN
# Brazil                     85626940.0   87363190.0   85319580.0   90075170.0
# France                     37570700.0   36169630.0   34776620.0   34377050.0
# Germany                    30391720.0   29285100.0   28460270.0   28778000.0
# Italy                      26710580.0   26063090.0   24948040.0   24706710.0
# Argentina                  27948600.0   30800780.0   30957870.0   33832140.0
# Indonesia                  34029230.0   35016270.0   36616890.0   38001410.0
#
# Year                             Total
# Country
# China                     8.455387e+09
# United States of America  6.368178e+09
# India                     4.507150e+09
# USSR                      3.224529e+09
# Brazil                    2.047309e+09
# France                    1.525771e+09
# Germany                   1.332990e+09
# Italy                     1.125765e+09
# Argentina                 9.145673e+08
# Indonesia                 8.764966e+08
#
# [10 rows x 48 columns]

# %%
print('Top 10 countries production in 1961', filtered_df[1961].sum(axis = 0, skipna = True))
other_1961_prod = world_1961_prod - filtered_df[1961].sum(axis = 0, skipna = True)
print('Other countries production in 1961', other_1961_prod)

print('Top 10 countries production in 2007', filtered_df[2007].sum(axis = 0, skipna = True))
other_2007_prod = world_2007_prod - filtered_df[2007].sum(axis = 0, skipna = True)
print('Other countries production in 2007', other_2007_prod)
# Out:
# Top 10 countries production in 1961 607541893.0
# Other countries production in 1961 Country
# World +    107.0
# Name: 1961, dtype: float64
# Top 10 countries production in 2007 1692537702.0
# Other countries production in 2007 Country
# World +    298.0
# Name: 2007, dtype: float64

# %%
def plot_piechart(df, keys, title):
    
    palette_color = sns.color_palette('bright')
    plt.figure(figsize=(16,8))  
    # plotting data on chart
    plt.pie(df, labels=keys, colors=palette_color, autopct='%.0f%%')
    plt.title(title)
    # displaying chart
    plt.show()

# %%
df_1961 = filtered_df[1961].head(10).append(other_1961_prod)
df_1961 = df_1961.rename(index = {'World +':"Other"})
keys = df_1961.index
title = "Top Agricultural Producing nations in 1961"
plot_piechart(df_1961, keys, title)
# Out:
# C:\Users\saumy\AppData\Local\Temp\ipykernel_23456\1832342914.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_1961 = filtered_df[1961].head(10).append(other_1961_prod)

# %%
df_2007 = filtered_df[2007].head(10).fillna(0).append(other_2007_prod)
df_2007 = df_2007.rename(index = {'World +':"Other"})
keys = df_2007.index
title = "Top Agricultural Producing nations in 2007"
plot_piechart(df_2007, keys, title)
# Out:
# C:\Users\saumy\AppData\Local\Temp\ipykernel_23456\1143470753.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_
# 1965      7925503.0
# 1966      8219212.0
# 1967      7840406.0
# 1968      9096512.0
# 1969      9155070.0
# 1970      9704501.0
# 1971     10007550.0
# 1972     10034870.0
# 1973     10815040.0
# 1974     11274650.0
# 1975     11142450.0
# 1976     11206520.0
# 1977     11646970.0
# 1978     12448370.0
# 1979     12983760.0
# 1980     14047620.0
# 1981     15063670.0
# 1982     14841610.0
# 1983     16082280.0
# 1984     17468570.0
# 1985     17965220.0
# 1986     18926660.0
# 1987     19170230.0
# 1988     20268510.0
# 1989     21354870.0
# 1990     22305680.0
# 1991     22569510.0
# 1992     24558050.0
# 1993     24864060.0
# 1994     25080400.0
# 1995     27342810.0
# 1996     27588090.0
# 1997     26436480.0
# 1998     26614870.0
# 1999     26909240.0
# 2000     27894050.0
# 2001     28467300.0
# 2002     30238130.0
# 2003     32107000.0
# 2004     34029230.0
# 2005     35016270.0
# 2006     36616890.0
# 2007     38001410.0

# %%
df_filled = df.fillna(0)
print(range(len(df_filled)))
print(df_filled.index.dtype)
print(range(df_filled.index.tolist()[0], df_filled.index.tolist()[-1]+1))
# Out:
# range(0, 47)
# object
# range(1961, 2008)

# %%
# Create a line plot

def plot_lineplot(df):
    fig, ax3 = plt.subplots(1, figsize=(16,8)) 
    sns.lineplot(data=df)
    label_format = '{:,.0f}'
    plt.xlim([df.index.tolist()[0], df.index.tolist()[-1]])
    plt.title("Top Agricultural Producing nations over years")
    plt.xlabel("Year")
    plt.ylabel("Gross Production in 1000 Int.$")
    plt.grid()

    #Set xticks for every year
    #UserWarning: FixedFormatter should only be used together with FixedLocator
    #https://stackoverflow.com/questions/63723514/userwarning-fixedformatter-should-only-be-used-together-with-fixedlocator
    ax3.xaxis.set_major_locator(mticker.MaxNLocator(47))
    ticks_loc = ax3.get_xticks().tolist()
    ax3.xaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
    ax3.set_xticklabels([label_format.format(x) for x in ticks_loc], rotation=45)
    # Show the plot
    plt.show()

# %%
plot_lineplot(df_filled)

# %%
# Create a histogram
def plot_boxplot(df):
    plt.figure(figsize=(16,8)) # this creates a figure 8 inch wide, 4 inch high
    ax = sns.boxplot(data=df)

    # Customize the plot
    plt.tight_layout()
    plt.title("Top Agricultural Producing nations over years")
    plt.xlabel("Year")
    plt.ylabel("Gross Production in 1000 Int.$")

    # Show the plot
    plt.show()

# %%
plot_boxplot(df_filled)

# %%
# Create a histogram
def plot_histogram(df):
    plt.figure(figsize=(16,8)) # this creates a figure 8 inch wide, 4 inch high
    num_bins = len(df_filled)
    sns.histplot(df, bins=num_bins, kde=False)

    # Customize the plot
    plt.tight_layout()
    plt.title("Top Agricultural Producing nations over years")
    plt.xlabel("Year")
    plt.ylabel("Gross Production in 1000 Int.$")

    # Show the plot
    plt.show()

# %%
# plot_histogram(df_filled)

# %%
df_filled = df_filled.reset_index() #reset_index() method allows you reset the index back to the default 0, 1, 2 etc indexes
df_reg = df_filled[['Year', 'China', 'United States of America', 'India', 'USSR', 'Brazil', 'France', 'Germany', 'Italy', 'Argentina', 'Indonesia']].copy()
df_reg.head()
# Out:
# Country  Year       China  United States of America       India        USSR  \
# 0        1961  58340740.0                89816580.0  50142680.0  72768810.0
# 1        1962  60690860.0                90275010.0  50015760.0  73961920.0
# 2        1963  63942700.0                93700380.0  51367730.0  70531000.0
# 3        1964  68462610.0                94323650.0  52267720.0  81216890.0
# 4        1965  74747900.0                97704050.0  49498330.0  80941960.0
#
# Country      Brazil      France     Germany       Italy   Argentina  Indonesia
# 0        16564600.0  23408500.0  22077690.0  18638310.0  11950390.0  7383684.0
# 1        17344940.0  26654000.0  24241470.0  19289340.0  12519320.0  8054871.0
# 2        17443010.0  25202710.0  25340780.0  18918070.0  13694660.0  7650931.0
# 3        17658130.0  25321080.0  24843610.0  19893760.0  12918230.0  8076970.0
# 4        20367240.0  26780910.0  23988490.0  20564500.0  12247380.0  7925503.0

# %%
#Linear Regression

from sklearn import linear_model
from sklearn.metrics import mean_squared_error
def plot_linear_reg(df_reg, country):
    data_years = df_reg[['Year']].values
    prod_country = df_reg[[country]].values

    future_years = np.arange(2008, 2019).reshape(-1, 1) #-1 infers the appropriate number of rows, 1 column vector

    # Create linear regression object
    regr = linear_model.LinearRegression()

    # Train the model using the training sets
    regr.fit(data_years, prod_country)

    # Make predictions for future years
    pred_country = regr.predict(future_years)

    # Calculate accuracy
    y_pred = regr.predict(data_years)
    mse = mean_squared_error(prod_country, y_pred)
    print("MSE for country " +country+ " is: "+str(mse))
#     percentage_mse = (mse / (prod_country.max() - prod_country.min())) * 100
#     print("Accuracy for country "+country+" is: "+str(percentage_mse))

    # Prediction for all years
    years = np.concatenate((data_years, future_years), axis=0) #Concatenate arrays vertically
    all_pred_country = regr.predict(years)

    plt.suptitle('Linear regression for '+str(country))
    plt.subplot(2,1,1)
    plt.plot(data_years, prod_country, '*', label = 'Actual data')
    plt.plot(years, all_pred_country,'.',label = 'Predicted data')
    plt.xlim([min(years), max(years)])
    plt.legend()
    plt.subplot(2,1,2)
    plt.plot(data_years, abs(y_pred-prod_country),label = 'Abs error')
    plt.xlim([min(years), max(years)])
    plt.legend()
    plt.show()
    # print("Mean squared error: %.2f" % mean_squared_error(y, pred))

    # print(np.mean((pred-y)**2))

# %%
countries = np.array(['China', 'United States of America', 'India', 'Brazil', 'France']) #Top 5 countries excluding USSR
for country in countries:
    plot_linear_reg(df_reg, country)
# Out:
# MSE for country China is: 729737615449292.1
# MSE for country United States of America is: 29906972116552.062
# MSE for country India is: 50183467039575.64
# MSE for country Brazil is: 25719339968962.04
# MSE for country France is: 2853586235157.9717

# %%
#Ridge regression
def plot_ridge_reg(df_reg, country):
    data_years = df_reg[['Year']].values
    prod_country = df_reg[[country]].values

    future_years = np.arange(2008, 2019).reshape(-1, 1) #-1 infers the appropriate number of rows, 1 column vector

    # Create linear regression object
    regr = linear_model.Ridge(alpha=1e-9)

    # Train the model using the training sets
    regr.fit(data_years, prod_country)

    # Make predictions for future years
    pred_country = regr.predict(future_years)

    # Calculate accuracy
    y_pred = regr.predict(data_years)
    mse = mean_squared_error(prod_country, y_pred)
    print("MSE for country " +country+ " is: "+str(mse))
#     percentage_mse = (mse / (prod_country.max() - prod_country.min())) * 100
#     print("Accuracy for country "+country+" is: "+str(percentage_mse))

    # Prediction for all years
    years = np.concatenate((data_years, future_years), axis=0) #Concatenate arrays vertically
    all_pred_country = regr.predict(years)

    plt.suptitle('Ridge regression for '+str(country))
    plt.subplot(2,1,1)
    plt.plot(data_years, prod_country, '*', label = 'Actual data')
    plt.plot(years, all_pred_country,'.',label = 'Predicted data')
    plt.xlim([min(years), max(years)])
    plt.legend()
    plt.subplot(2,1,2)
    plt.plot(data_years, abs(y_pred-prod_country),label = 'Abs error')
    plt.xlim([min(years), max(years)])
    plt.legend()
    plt.show()

# %%
countries = np.array(['China', 'United States of America', 'India', 'Brazil', 'France']) #Top 5 countries excluding USSR
for country in countries:
    plot_ridge_reg(df_reg, country)
# Out:
# MSE for country China is: 729737615449292.8
# MSE for country United States of America is: 29906972116551.67
# MSE for country India is: 50183467039578.555
# MSE for country Brazil is: 25719339968962.598
# MSE for country France is: 2853586235157.994

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

def plot_random_forest_reg(df_reg, country):
    data_years = df_reg[['Year']].values
    prod_country = df_reg[[country]].values

    future_years = np.arange(2008, 2019).reshape(-1, 1) #-1 infers the appropriate number of rows, 1 column vector

    # Create random forest object
    regr = RandomForestRegressor(max_depth=10, random_state=0)

    regr.fit(data_years, prod_country)

    # Make predictions for future years
    pred_country = regr.predict(future_years)
    print(pred_country)
    
    # Calculate MSE
    y_pred = regr.predict(data_years)
    mse = metrics.mean_squared_error(prod_country, y_pred)
    print("MSE for country " +country+ " is: "+str(mse))

    # Prediction for all years
    years = np.concatenate((data_years, future_years), axis=0) #Concatenate arrays vertically
    all_pred_country = regr.predict(years)

    plt.suptitle('Random forest for '+str(country))
    plt.plot(data_years, prod_country, '*', label = 'Actual data')
    plt.plot(years, all_pred_country,'.',label = 'Predicted data')
    plt.legend()
    plt.show()

# %%
countries = np.array(['China', 'United States of America', 'India', 'Brazil', 'France']) #Top 5 countries excluding USSR
for country in countries:
    plot_random_forest_reg(df_reg, country)
# Out:
# C:\Users\saumy\AppData\Local\Temp\ipykernel_23456\708172208.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(data_years, prod_country)
# [3.81102627e+08 3.81102627e+08 3.81102627e+08 3.81102627e+08
#  3.81102627e+08 3.81102627e+08 3.81102627e+08 3.81102627e+08
#  3.81102627e+08 3.81102627e+08 3.81102627e+08]
# MSE for country China is: 4370287354821.673
# [1.82064451e+08 1.82064451e+08 1.82064451e+08 1.82064451e+08
#  1.82064451e+08 1.82064451e+08 1.82064451e+08 1.82064451e+08
#  1.82064451e+08 1.82064451e+08 1.82064451e+08]
# MSE for country United States of America is: 5950958617982.938
# C:\Users\saumy\AppData\Local\Temp\ipykernel_23456\708172208.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(data_years, prod_country)
# C:\Users\saumy\AppData\Local\Temp\ipykernel_23456\708172208.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(data_years, prod_country)
# [1.6931557e+08 1.6931557e+08 1.6931557e+08 1.6931557e+08 1.6931557e+08
#  1.6931557e+08 1.6931557e+08 1.6931557e+08 1.6931557e+08 1.6931557e+08
#  1.6931557e+08]
# MSE for country India is: 2775039078677.5063
# C:\Users\saumy\AppData\Local\Temp\ipykernel_23456\708172208.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(data_years, prod_country)
# [88122170.1 88122170.1 88122170.1 88122170.1 88122170.1 88122170.1
#  88122170.1 88122170.1 88122170.1 88122170.1 88122170.1]
# MSE for country Brazil is: 444603721259.9919
# C:\Users\saumy\AppData\Local\Temp\ipykernel_23456\708172208.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(data_years, prod_country)
# [34837784.7 34837784.7 34837784.7 34837784.7 34837784.7 34837784.7
#  34837784.7 34837784.7 34837784.7 34837784.7 34837784.7]
# MSE for country France is: 224346962208.05893
